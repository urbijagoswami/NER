# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from transformers import (AutoTokenizer, AutoConfig,
                              AutoModelForSequenceClassification, TrainingArguments, Trainer)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
model_checkpoint="bert-base-uncased"

# %%
#model_checkpoint="biobert-base-uncased"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
from transformers import DataCollatorForTokenClassification


data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# %%
# sentence_tokens=[]

# texts = open(r"/kaggle/input/annotated/copious_published/train/100785_English_120409_32367238_1954.txt","r")

# #texts = ["GRAKLE.147 wing coverts, quills, and tail black brown, the last three inches and a half in length ; legs brown. Inhabits the Philippine Islands, and said to build the nest in hollow trees, especially the cocoa nut ; lives on fruits, is very voracious, soon digesting what it eats, insomuch that a vulgar error has arisen, of there being no circumvolution of intestines, but only one strait passage from the mouth to the vent ; it is reported to be a noisy, chattering bird, and when irritated, the bare part about the head changes to a deep red.It varies in having the under parts brown, spotted with white ; and in some the under parts are yellow brown.Sonnerat mentions one, which was two inches longer  the feathers surrounding the naked part of the head, and down the middle of it, black; under parts of the body the same; wings, tail, and upper parts grey, lightest on the rump and neck.One, similar to the above, twelve inches long, the tail four inches and a half, inhabits India, and called Gogoye ; but this seems not peculiar, as others of a different Genus, such as the Crying and Chinese Thrushes, are called by the same name.3— PARADISE GRAKLE.Gracula tristis, Ind.Orn.190.Lin.Syst.167; Gm.Lini.401.(Paradisea)Shaiv's Zool. vii.455.Gracula grillivora, Daud. ii.285.Merula Philippensis, Bris. iu 278. t. 26. f. 1.Td.Svo. i. 235.Martin, Bii. iii.423.EssPhilosophy. p. 44.Merle des Philippines, PI. enl.219.Paradise Grakle, Gen. Syn. ii.458.Id.Sup. ii.127.LENGTH nine inches and a half Bill yellow; irides dove-colour; the upper part of the head covered with narrow blackfeathers, similar to those of the Bird of Paradise ; behind the eyes a U 2"]
# for doc in nlp.pipe(texts):
    
#     sentence_tokens.append([[token.text for token in sent] for sent in doc.sents])

# %%
df0=pd.DataFrame(columns=["name","tokens"])

# %%
df_tr0=pd.DataFrame(columns=["name","tokens"])

# %%
import spacy 
nlp = spacy.load("en_core_web_lg")

# %%
# df_train=pd.read_csv("/kaggle/input/train-dev-ner/train.csv")
# df_dev=pd.read_csv("/kaggle/input/train-dev-ner/dev.csv")
# df_train=df_train.drop(df_train.columns[0],axis=1)
# df_dev=df_dev.drop(df_dev.columns[0],axis=1)

# %%
# import nltk
# nltk.download('punkt')  # Download the necessary data for tokenization

# from nltk.tokenize import sent_tokenize
# with open("/kaggle/input/annotated/copious_published/dev/104421_English_33451118_1922-26..txt","r") as texts:
#     file=texts.read()

# for doc in sent_tokenize(file):
    
    
    
#     encoding = tokenizer.convert_ids_to_tokens(tokenizer.encode(doc))
#     print(encoding)

# %%
for file in os.listdir("/kaggle/input/annotated/copious_published/dev"):
    if(file.endswith('.txt') or file.endswith('..txt')):
        
        texts = open("/kaggle/input/annotated/copious_published/dev/"+file,"r")

        sentence_tokens=[]

        for doc in nlp.pipe(texts):
            sentence_tokens.append([[token.text for token in sent] for sent in doc.sents])
        dic={"name":file,"tokens":sentence_tokens}

        df0=df0.append(dic,ignore_index=True)
# Out:
# /tmp/ipykernel_32/3751064321.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df0=df0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/3751064321.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df0=df0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/3751064321.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df0=df0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/3751064321.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df0=df0.append(dic,ignore_index=True)
# ...

# %%
pip install mendelai-brat-parser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mendelai-brat-parser: filename=mendelai_brat_parser-0.0.11-py3-none-any.whl size=4943 sha256=ff1ca51d64c22f0a3b1fa86c13b1a3336f2084068c6985db74a443260b2cdce2
#   Stored in directory: /root/.cache/pip/wheels/66/6d/54/75653ad4624c60f22e21173848881fdf2af79baafab35e13a9
# Successfully built mendelai-brat-parser
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from brat_parser import get_entities_relations_attributes_groups

#entities, relations, attributes, groups = get_entities_relations_attributes_groups("/kaggle/input/annotated/copious_published/train/100785_English_120409_32367238_1954.ann")

# %%
df1=pd.DataFrame(columns=["name","ann_text","ann_tag"])

# %%
df2=pd.DataFrame(columns=["name","ann_text","ann_tag"])

# %%
dic={}
for file in os.listdir("/kaggle/input/annotated/copious_published/dev"):
    if(file.endswith('..ann') or file.endswith('.ann')):
        

        entities, relations, attributes, groups = get_entities_relations_attributes_groups("/kaggle/input/annotated/copious_published/dev/"+file)
        l=[]
        l1=[]
        for i in entities.keys():
            a1=entities[i]
            b1=a1.text
            c1=a1.type
            l.append(b1)
            l1.append(c1)
        dic={"name":file,"ann_text":l,"ann_tag":l1}
        
        df2=df2.append(dic,ignore_index=True)
# Out:
# /tmp/ipykernel_32/2912090132.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2=df2.append(dic,ignore_index=True)
# /tmp/ipykernel_32/2912090132.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2=df2.append(dic,ignore_index=True)
# /tmp/ipykernel_32/2912090132.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2=df2.append(dic,ignore_index=True)
# /tmp/ipykernel_32/2912090132.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2=df2.append(dic,ignore_index=True)
# ...

# %%
df2
# Out:
#                                       name  \
# 0                             34179045.ann
# 1                             37190474.ann
# 2                             36442110.ann
# 3                             28831271.ann
# 4         109841_English_35421888_1906.ann
# ..                                     ...
# 62  107004_English_78294_34354191_1912.ann
# 63    104421_English_33451123_1922-26..ann
# 64  107004_English_78294_34354195_1912.ann
# 65        111121_English_36025302_1908.ann
# 66  107004_English_78294_34354169_1912.ann
#
#                                              ann_text  \
# 0   [DIPTEEOCARPACEAE, A. glabra, A. glabra, Kurz,...
# 1   [Malayan Peninsula, D. laevis, D. tuberculatus...
# 2   [Dipterocarpaceae, Shorea, tropical forests, M...
# 3   [Malesia, Philippines, Zamboanga, Mindanao, Va...
# 4   [Japan, Oshima, Riukiu Islands, Tokyo, Japan, ...
# ..                                                ...
# 62  [PHILIPPINE ISLANDS, Sus inconstans, Sus incon...
# ...

# %%
df_dev=pd.DataFrame(columns=["tokens","tag"])

# %%
df2
# Out:
#                                       name  \
# 0                             34179045.ann
# 1                             37190474.ann
# 2                             36442110.ann
# 3                             28831271.ann
# 4         109841_English_35421888_1906.ann
# ..                                     ...
# 62  107004_English_78294_34354191_1912.ann
# 63    104421_English_33451123_1922-26..ann
# 64  107004_English_78294_34354195_1912.ann
# 65        111121_English_36025302_1908.ann
# 66  107004_English_78294_34354169_1912.ann
#
#                                              ann_text  \
# 0   [DIPTEEOCARPACEAE, A. glabra, A. glabra, Kurz,...
# 1   [Malayan Peninsula, D. laevis, D. tuberculatus...
# 2   [Dipterocarpaceae, Shorea, tropical forests, M...
# 3   [Malesia, Philippines, Zamboanga, Mindanao, Va...
# 4   [Japan, Oshima, Riukiu Islands, Tokyo, Japan, ...
# ..                                                ...
# 62  [PHILIPPINE ISLANDS, Sus inconstans, Sus incon...
# ...

# %%
import string
y=list(string.punctuation)
y.append('\n')
for i in range(len(df0)):
    flattened_list=[]
    n=(df0["tokens"].iloc[i,])
    flattened_list = [word for sublist in n for sentence in sublist for word in sentence]
    flattened_list= [x for x in flattened_list if x not in y]
    df0["tokens"].iloc[i,]=flattened_list

# %%
df0
# Out:
#                                     name  \
# 0   104421_English_33451118_1922-26..txt
# 1                           28549848.txt
# 2                           34179045.txt
# 3                           11364519.txt
# 4       109841_English_35421956_1906.txt
# ..                                   ...
# 62      109841_English_35421830_1906.txt
# 63      104481_English_33474555_1822.txt
# 64      111121_English_36025302_1908.txt
# 65      109841_English_35421952_1906.txt
# 66                          37190475.txt
#
#                                                tokens
# 0   [44, ENUMERATION, OF, PHILIPPINE, PLANTS, 1922...
# 1   [—, 324, —, Fruit, one, seeded, by, abortion, ...
# 2   [Anisoptera, XVII, DIPTEEOCARPACEAE, 67, 1, A....
# 3   [ , 22, J., Perkins, Dipterocarpaceae, by, J.,...
# 4   [AUTOPSIES, AT, THE, PHILIPPINE, MEDICAL, SCHO...
# ..                                                ...
# 62  [ILLUSTRATIONS, Plates, I, and, II, Houses, in...
# ...

# %%
df_dev
# Out:
# Empty DataFrame
# Columns: [tokens, tag]
# Index: []

# %%
# p=df0["tokens"].iloc[0,][59]+" "+df0["tokens"].iloc[0,][60]
# i=0
# p in df2["ann_text"].iloc[51,]
# df2.iloc[51,]["ann_tag"][df2.iloc[51,]["ann_text"].index('ANDROPOGON CONTORTUS')]

# %%
#df_dev["tokens"].iloc[0,]

# %%
#del df_dev["tags"]

# %%
list(string.punctuation)
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
#df0.iloc[0,]["tokens"]

# %%
'Andropogon squarrosus Linn. f. var. nigritanus Hack' in df_dev["tokens"].iloc[0]
# df_dev["tokens"].iloc[0,].index('1878')
# df_dev["tag"].iloc[0,][444]
#len(df0["tokens"].iloc[0,])
# Out:
# False

# %%
# for i in df2.iloc[51,]["ann_text"]:
#     if i not in df_dev["tokens"].iloc[0,]:
#         print(i)
# Out:
# tang-lad
# Heteropogon contortus Beauv.
# Sibat-sibatan
# ANDROPOGON FASTIGIATUS Sw.
# dry slopes
# open slopes
# Andropogon nigritanus Benth.
# Andropogon squarrosus Linn.
# rice-paddy banks
# LACHNATHERUS (Benth)
# LACHNATHERUS (Benth) Hack
# Andropogon muricatus Retz. var. aristatus Biise
# Vetiveria zizanioides Stapf var. nigritana Camus
# Andropogon squarrosus Linn. f. var. nigritanus Hack

# %%
df0.iloc[0,]["name"]
# Out:
# '104421_English_33451118_1922-26..txt'

# %%
df_dev.iloc[0,]["tokens"].index('Urban')
df_dev.iloc[0,]["tag"][436]
# Out:
# 'O'

# %%
for i in range(len(df0)):
    for j in range(len(df2)):
        if df0.iloc[i]["name"].split('.txt') == df2.iloc[j]["name"].split('.ann'):
            p = 0
            a = []
            l = []

            for k in df0.iloc[i]["tokens"]:
                matched = False

                # Check if the token exists in df2
                if k in df2.iloc[j]["ann_text"]:
                    b = k
                    a.append(b)
                    l.append(df2.iloc[j]["ann_tag"][df2.iloc[j]["ann_text"].index(b)])
                    matched = True

                # Check for longer sequences
                for n in range(1, 8):
                    if p <= len(df0.iloc[i]["tokens"]) - n:
                        seq = " ".join(df0.iloc[i]["tokens"][p:p + n])
                        if seq in df2.iloc[j]["ann_text"]:
                            a.append(seq)
                            
                            l.append(df2.iloc[j]["ann_tag"][df2.iloc[j]["ann_text"].index(seq)])
                            matched = True
                        

                # If no match was found, add 'O'
                if not matched:
                    a.append(k)
                    l.append('O')

                p += 1

            dic = {"tokens": a, "tag": l}
            df_dev = df_dev.append(dic, ignore_index=True)
# Out:
# /tmp/ipykernel_32/2924804501.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dev = df_dev.append(dic, ignore_index=True)
# /tmp/ipykernel_32/2924804501.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dev = df_dev.append(dic, ignore_index=True)
# /tmp/ipykernel_32/2924804501.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dev = df_dev.append(dic, ignore_index=True)
# /tmp/ipykernel_32/2924804501.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dev = df_dev.append(dic, ignore_index=True)
# ...

# %%
# for i in range(len(df0)):

#         for j in range(len(df2)):
#             if(df0.iloc[i,]["name"].split('.txt')==df2.iloc[j,]["name"].split('.ann')):
#                 p=0
                
#                 a=[]
#                 l=[]
                


#                 for k in df0.iloc[i,]["tokens"]:
                    
                    
#                     if(p<=(len(df0.iloc[i,]["tokens"])-1)):
#                             if (k in df2.iloc[j,]["ann_text"]):
#                                 b=k
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
                    
#                     if(p<=(len(df0.iloc[i,]["tokens"])-2)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
#                     if(p<=(len(df0.iloc[i,]["tokens"])-3)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
#                     if(p<=(len(df0.iloc[i,]["tokens"])-4)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
#                     if(p<=(len(df0.iloc[i,]["tokens"])-5)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
#                     if(p<=(len(df0.iloc[i,]["tokens"])-6)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4]+" "+df0.iloc[i,]["tokens"][p+5] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4]+" "+df0.iloc[i,]["tokens"][p+5]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
#                     if(p<=(len(df0.iloc[i,]["tokens"])-7)):
#                             if (k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4]+" "+df0.iloc[i,]["tokens"][p+5]+" "+df0.iloc[i,]["tokens"][p+6] in df2.iloc[j,]["ann_text"]):
#                                 b=k+" "+df0.iloc[i,]["tokens"][p+1]+" "+df0.iloc[i,]["tokens"][p+2]+" "+df0.iloc[i,]["tokens"][p+3]+" "+df0.iloc[i,]["tokens"][p+4]+" "+df0.iloc[i,]["tokens"][p+5]+" "+df0.iloc[i,]["tokens"][p+6]
#                                 a.append(b)
#                                 l.append(df2.iloc[j,]["ann_tag"][df2.iloc[j,]["ann_text"].index(b)])
# #                     else:
# #                         a.append(k)
# #                         l.append('O')
                                
                    
                    
#                     p+=1
#         dic={"tokens":a,"tag":l}
#         df_dev=df_dev.append(dic,ignore_index=True)

# %%
m.iloc[0,]["tag"][15]
# Out:
# 'I-Taxon'

# %%
n=pd.DataFrame(columns=df_train.columns)
m=pd.DataFrame(columns=df_dev.columns)

# %%
for i in range(len(df_dev)):
    tokens_list = []  # List to store tokens for the current row
    tags_list = [] 
    
    for k in range(len(df_dev["tokens"].iloc[i,])):
        
        
        tokens = df_dev["tokens"].iloc[i,][k].split()  # Split the tokens into individual words
        tag = df_dev["tag"].iloc[i,][k]
        for j, token in enumerate(tokens):
                if j == 0:
                    b = 'B-' + tag
                else:
                    b = 'I-' + tag

                # Append the token and tag to the modified DataFrame
                tokens_list.append(token)
                tags_list.append(b)
                tags_list1=[x.replace('B-O','O') for x in tags_list]
                

        
        
           
    m = m.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# Out:
# /tmp/ipykernel_32/281955504.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   m = m.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/281955504.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   m = m.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/281955504.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   m = m.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/281955504.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   m = m.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# ...

# %%
# Out:
# 527

# %%
b
# Out:
# ['B-O', 'I-O', 'I-O']

# %%
df_dev
# Out:
#                                                tokens  \
# 0   [Balioko, barani, paja de mesa, salai, sai, sa...
# 1   [S. reticulatus, N. kanneliyensis, S. reticula...
# 2   [DIPTEEOCARPACEAE, A. glabra, Thin kadu, Pegu,...
# 3   [Perkins, Dipterocarpaceae, Peekins, Dipteroca...
# 4   [Tuberculous peritonitis, guinea pigs, five, c...
# ..                                                ...
# 62  [Farola, 1902, Philippines, Manila Bay, Laguna...
# 63  [Mina, Hill Moina, China, Lefkoa, Canton, Java...
# 64  [MINDANAO, SULU, G. F. Becker, Becker, Sainz d...
# 65  [Philippine Islands, Manila, Bilibid Prison, P...
# 66  [Malayan Peninsula, Dyer, Parinarium, Petrocar...
#
#                                                   tag
# 0   [Taxon, Taxon, Taxon, Taxon, Taxon, Taxon, Tax...
# 1   [Taxon, Taxon, Taxon, Taxon, Taxon, Taxon, Tax...
# 2   [Taxon, Taxon, Taxon, GeographicalLocation, Ge...
# 3   [Person, Taxon, Person, Taxon, Taxon, Taxon, P...
# ...

# %%
df2.iloc[15,]["ann_text"].count('ARUNDINELLA M I LI ACE A Nees')
# Out:
# 1

# %%
(df0.iloc[56,]["tokens"][263])
# Out:
# 'Nees'

# %%
dic={}
for file in os.listdir("/kaggle/input/annotated/copious_published/train"):
    if(file.endswith('..ann') or file.endswith('ann')):
        

        entities, relations, attributes, groups = get_entities_relations_attributes_groups("/kaggle/input/annotated/copious_published/train/"+file)
        l=[]
        l1=[]
        for i in entities.keys():
            a=entities[i]
            b=a.text
            c=a.type
            l.append(b)
            l1.append(c)
        dic={"name":file,"ann_text":l,"ann_tag":l1}
        
        df1=df1.append(dic,ignore_index=True)
# Out:
# /tmp/ipykernel_32/521595813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(dic,ignore_index=True)
# /tmp/ipykernel_32/521595813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(dic,ignore_index=True)
# /tmp/ipykernel_32/521595813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(dic,ignore_index=True)
# /tmp/ipykernel_32/521595813.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(dic,ignore_index=True)
# ...

# %%
df_tr0
# Out:
#                                      name  \
# 0      44148_English_12096466_unknown.txt
# 1         39410_English_10262308_1954.txt
# 2         99366_English_31853754_1956.txt
# 3                            38627554.txt
# 4                              694855.txt
# ..                                    ...
# 529     35334_English_8689460_unknown.txt
# 530                            692399.txt
# 531      119097_English_38679200_2008.txt
# 532                          41827930.txt
# 533  20889_English_19033_2765261_1935.txt
#
#                                                 tokens
# 0    [[[32, ME, .], [p., H., CARPENTER, OX, THE, GE...
# 1    [[[season, it, gradually, becomes, more, dispe...
# 2    [[[58, \n]], [[COMMERCIAL, FISHERIES, REVIEW, ...
# 3    [[[VATERIA, MALABARICA, .], [(, Nat, ., order,...
# 4    [[[188, The, Philippine, Journal, of, Science,...
# ..                                                 ...
# 529  [[[from, the, Philippine, Islands, .], [97, \n...
# ...

# %%
for file in os.listdir("/kaggle/input/annotated/copious_published/train"):
    if(file.endswith('.txt') or file.endswith('..txt')):
        
        texts = open("/kaggle/input/annotated/copious_published/train/"+file,"r")

        sentence_tokens=[]

        for doc in nlp.pipe(texts):
            sentence_tokens.append([[token.text for token in sent] for sent in doc.sents])
        dic={"name":file,"tokens":sentence_tokens}

        df_tr0=df_tr0.append(dic,ignore_index=True)
# Out:
# /tmp/ipykernel_32/1323587221.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tr0=df_tr0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/1323587221.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tr0=df_tr0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/1323587221.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tr0=df_tr0.append(dic,ignore_index=True)
# /tmp/ipykernel_32/1323587221.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tr0=df_tr0.append(dic,ignore_index=True)
# ...

# %%
y=list(string.punctuation)
y.append('\n')
for i in range(len(df_tr0)):
    flattened_list=[]
    n=(df_tr0["tokens"].iloc[i,])
    flattened_list = [word for sublist in n for sentence in sublist for word in sentence]
   

    flattened_list= [x for x in flattened_list if x not in y]
    
    df_tr0["tokens"].iloc[i,]=flattened_list

# %%
df_tr0
# Out:
#                                      name  \
# 0      44148_English_12096466_unknown.txt
# 1         39410_English_10262308_1954.txt
# 2         99366_English_31853754_1956.txt
# 3                            38627554.txt
# 4                              694855.txt
# ..                                    ...
# 529     35334_English_8689460_unknown.txt
# 530                            692399.txt
# 531      119097_English_38679200_2008.txt
# 532                          41827930.txt
# 533  20889_English_19033_2765261_1935.txt
#
#                                                 tokens
# 0    [32, ME, p., H., CARPENTER, OX, THE, GENUS, AC...
# 1    [season, it, gradually, becomes, more, dispers...
# 2    [58, COMMERCIAL, FISHERIES, REVIEW, Vol, 18, N...
# 3    [VATERIA, MALABARICA, Nat, order, Dipterocarpe...
# 4    [188, The, Philippine, Journal, of, Science, w...
# ..                                                 ...
# 529  [from, the, Philippine, Islands, 97, Tabanidae...
# ...

# %%
df_train=pd.DataFrame(columns=df_dev.columns)

# %%
for i in range(len(df_tr0)):
    for j in range(len(df1)):
        if(df_tr0.iloc[i,]["name"].split('.txt')==df1.iloc[j,]["name"].split('.ann')):
            p = 0
            a = []
            l = []

            for k in df_tr0.iloc[i]["tokens"]:
                matched = False

                # Check if the token exists in df2
                if k in df1.iloc[j]["ann_text"]:
                    b = k
                    a.append(b)
                    l.append(df1.iloc[j]["ann_tag"][df1.iloc[j]["ann_text"].index(b)])
                    matched = True

                # Check for longer sequences
                for n in range(1, 8):
                    if p <= len(df_tr0.iloc[i]["tokens"]) - n:
                        seq = " ".join(df_tr0.iloc[i]["tokens"][p:p + n])
                        if seq in df1.iloc[j]["ann_text"]:
                            a.append(seq)
                            l.append(df1.iloc[j]["ann_tag"][df1.iloc[j]["ann_text"].index(seq)])
                            matched = True
                        

                # If no match was found, add 'O'
                if not matched:
                    a.append(k)
                    l.append('O')

                p += 1

            dic = {"tokens": a, "tag": l}
            df_train = df_train.append(dic, ignore_index=True)
# Out:
# /tmp/ipykernel_32/619095147.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(dic, ignore_index=True)
# /tmp/ipykernel_32/619095147.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(dic, ignore_index=True)
# /tmp/ipykernel_32/619095147.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(dic, ignore_index=True)
# /tmp/ipykernel_32/619095147.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(dic, ignore_index=True)
# ...

# %%
from tqdm import tqdm

# %%
df_train
# Out:
#                                                 tokens  \
# 0    [32, ME, p., H., CARPENTER OX, OX, THE, GENUS,...
# 1    [season, it, gradually, becomes, more, dispers...
# 2    [58, COMMERCIAL, FISHERIES, REVIEW, Vol, 18, N...
# 3    [VATERIA, VATERIA, VATERIA MALABARICA, MALABAR...
# 4    [188, The, Philippine, Journal, of, Science, w...
# ..                                                 ...
# 529  [from, the, Philippine Islands, Islands, 97, T...
# 530  [504, The, Philippine, Journal, of, Science, 1...
# 531  [Section, 1, Introduction, Table, 1, Examples,...
# 532  [276, NOTES, ON, DIPTEKOCARPS, DIPTEKOCARPS, l...
# 533  [68, FIELD, MUSEUM, OF, NATURAL, HISTORY, ZOOL...
#
#                                                    tag
# 0    [O, O, O, O, Taxon, O, O, O, Taxon, Taxon, O, ...
# 1    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2    [O, O, O, O, O, O, O, O, O, O, O, Geographical...
# 3    [Taxon, Taxon, Taxon, O, O, O, Taxon, Taxon, O...
# ...

# %%
df_train=df_train.drop(116)

# %%
n=pd.DataFrame(columns=["tokens","tag"])

# %%
n
# Out:
#                                                 tokens  \
# 0    [32, ME, p., H., CARPENTER, OX, OX, THE, GENUS...
# 1    [season, it, gradually, becomes, more, dispers...
# 2    [58, COMMERCIAL, FISHERIES, REVIEW, Vol, 18, N...
# 3    [VATERIA, VATERIA, VATERIA, MALABARICA, MALABA...
# 4    [188, The, Philippine, Journal, of, Science, w...
# ..                                                 ...
# 528  [from, the, Philippine, Islands, Islands, 97, ...
# 529  [504, The, Philippine, Journal, of, Science, 1...
# 530  [Section, 1, Introduction, Table, 1, Examples,...
# 531  [276, NOTES, ON, DIPTEKOCARPS, DIPTEKOCARPS, l...
# 532  [68, FIELD, MUSEUM, OF, NATURAL, HISTORY, ZOOL...
#
#                                                    tag
# 0    [O, O, O, O, B-Taxon, I-Taxon, O, O, O, B-Taxo...
# 1    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2    [O, O, O, O, O, O, O, O, O, O, O, B-Geographic...
# 3    [B-Taxon, B-Taxon, B-Taxon, I-Taxon, O, O, O, ...
# ...

# %%
for i in range(len(df_train)):
    tokens_list = []  # List to store tokens for the current row
    tags_list = [] 
    for k in range(len(df_train["tokens"].iloc[i,])):
        
        
        tokens = df_train["tokens"].iloc[i,][k].split()  # Split the tokens into individual words
        tag = df_train["tag"].iloc[i,][k]
        for j, token in enumerate(tokens):
                if j == 0:
                    b = 'B-' + tag
                else:
                    b = 'I-' + tag

                # Append the token and tag to the modified DataFrame
                tokens_list.append(token)
                tags_list.append(b)
                tags_list1=[x.replace('B-O','O') for x in tags_list]

        
       
            
    n = n.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# Out:
# /tmp/ipykernel_32/3563300685.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   n = n.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/3563300685.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   n = n.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/3563300685.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   n = n.append({'tokens': tokens_list, 'tag': tags_list1}, ignore_index=True)
# /tmp/ipykernel_32/3563300685.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
n.iloc[0,]["tokens"][5]
# Out:
# 'OX'

# %%
def tokenize_and_align_labels(examples,tokenizer):
    tokenized_inputs = tokenizer(examples["tokens"].tolist(), truncation=True, max_length=512,is_split_into_words=True)
    
    all_labels = examples["tag"].tolist()
    new_labels = []
    tokenized_data = []
    
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))
        #tokenized_data.append({"input_ids": tokenized_inputs['input_ids'][i], "attention_mask": tokenized_inputs['attention_mask'][i], "labels": labels})

    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs

# %%
columns_to_remove = ['name']
df1= df1.drop(columns_to_remove, axis=1)
df2= df2.drop(columns_to_remove, axis=1)

# %%
df_train
# Out:
#                                                 tokens  \
# 0    [CARPENTER OX, ACTINOMETRA, Greeff, Ludwig, Cr...
# 1    [black tuna, black tuna, black marlin, East Ph...
# 2    [Philippines, Philippines, 1954, 1953, 1952, 1...
# 3    [VATERIA, VATERIA MALABARICA, Dipterocarpeae, ...
# 4    [SHOREA CILIATA, Penang, Tabat, Pinagcamaligan...
# ..                                                 ...
# 529  [Philippine Islands, Tabanidae, Haematopota lu...
# 530  [Kwangtung Province, Tung Sing, Ts'oong, man l...
# 531  [Samoa, reefs, 2010, Australia, Soutin, Austra...
# 532  [DIPTEKOCARPS, Pachynocarpus, Vatica Zollinger...
# 533  [Mindoro, Philippines, J. B. Steere, Mindoro, ...
#
#                                                    tag
# 0    [Taxon, Taxon, Person, Person, Taxon, Taxon, T...
# 1    [Taxon, Taxon, Taxon, GeographicalLocation, Te...
# 2    [GeographicalLocation, GeographicalLocation, T...
# 3    [Taxon, Taxon, Taxon, Taxon, Person, Person, P...
# ...

# %%
def align_labels_with_tokens(labels, word_ids):
    new_labels = []
    current_word = None
    
    
    
    for word_id in word_ids:
        if word_id != current_word:
            # Start of a new word!
            current_word = word_id
            if word_id is None:
                new_labels.append(-100)
            else:
                label = labels[word_id]
                
                new_labels.append(label)
        elif word_id is None:
            # Special token
            new_labels.append(-100)
        else:
            # Same word as previous token
            label = labels[word_id]
            
            new_labels.append(label)
    
    return new_labels

# %%
# !pip install seqeval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=242d98eeaf61694f1965f92ab8888902cfe59b2332c90dc7427363296da1f07b
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# ...

# %%
# !pip install evaluate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import evaluate

metric = evaluate.load("seqeval")

# %%
df3=pd.DataFrame()

# %%
df4=pd.DataFrame()

# %%
# for i in range(len(df2)):
#     l1=[]
#     l=[]
#     p=0
#     for j in df2["ann_tag"].iloc[i,]:
#         #print(j)
        
        
#         if j != "GeographicalLocation":
            
            
#             l.append(df2["ann_tag"].iloc[i,][p])
#             l1.append(df2["ann_text"].iloc[i,][p])
#             dic={"ann_text":l1,"ann_tag":l}
#         p+=1

        
#     df3=df3.append(dic,ignore_index=True)

# %%
# for i in range(len(df1)):
#     l1=[]
#     l=[]
#     p=0
#     for j in df1["ann_tag"].iloc[i,]:
#         #print(j)
        
        
#         if j != "GeographicalLocation":
            
            
#             l.append(df1["ann_tag"].iloc[i,][p])
#             l1.append(df1["ann_text"].iloc[i,][p])
#             dic={"ann_text":l1,"ann_tag":l}
#         p+=1

        
#     df4=df4.append(dic,ignore_index=True)

# %%
#tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
df_dev
# Out:
#                                                tokens  \
# 0   [44, ENUMERATION, OF, PHILIPPINE, PLANTS, 1922...
# 1   [—, 324, —, Fruit, one, seeded, by, abortion, ...
# 2   [Anisoptera, XVII, DIPTEEOCARPACEAE, DIPTEEOCA...
# 3   [ , 22, J., Perkins, Perkins, Dipterocarpaceae...
# 4   [AUTOPSIES, AT, THE, PHILIPPINE, MEDICAL, SCHO...
# ..                                                ...
# 62  [ILLUSTRATIONS, Plates, I, and, II, Houses, in...
# 63  [146, GRAKLE, Mina, Mina, or, Hill Moina, Moin...
# 64  [GEOLOGIC, RECONNAISSANCE, OF, MINDANAO, MINDA...
# 65  [ANIMAL, PARASITES, OF, MAN, 209, intestinal, ...
# 66  [94, G., King, -Materials, for, a, Flora, of, ...
#
#                                                   tag
# 0   [O, O, O, O, O, O, O, O, Taxon, Taxon, O, Taxo...
# 1   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2   [O, O, Taxon, Taxon, O, O, Taxon, O, O, O, O, ...
# 3   [O, O, O, Person, Person, Taxon, Taxon, O, O, ...
# ...

# %%
b=tokenize_and_align_labels(n,tokenizer)
c=tokenize_and_align_labels(m,tokenizer)

# %%
# for i in range(len(df_train)):
#     if len(df_train["tokens"].iloc[i,])!=len(df_train["tag"].iloc[i,]):
#         print(i)

# %%
label_names = n["tag"].explode().unique()

# %%
label_names
# Out:
# array(['O', 'B-Taxon', 'I-Taxon', 'B-Person', 'B-TemporalExpression',
#        'B-GeographicalLocation', 'I-GeographicalLocation',
#        'I-TemporalExpression', 'B-Habitat', 'I-Habitat', 'I-Person'],
#       dtype=object)

# %%
#map={'Habitat':0, 'Taxon':1, 'Person':2, 'TemporalExpression':3,-100:-100
     
    
#}
map={'O':0, 'B-Taxon':1, 'I-Taxon':2, 'B-Person':3, 'B-TemporalExpression':4,
       'B-GeographicalLocation':5, 'I-GeographicalLocation':6,
       'I-TemporalExpression':7, 'B-Habitat':8, 'I-Habitat':9, 'I-Person':10,-100:-100
     
    
}

# %%
map
# Out:
# {'O': 0,
#  'B-Taxon': 1,
#  'I-Taxon': 2,
#  'B-Person': 3,
#  'B-TemporalExpression': 4,
#  'B-GeographicalLocation': 5,
#  'I-GeographicalLocation': 6,
#  'I-TemporalExpression': 7,
#  'B-Habitat': 8,
#  'I-Habitat': 9,
#  'I-Person': 10,
#  -100: -100}

# %%
b["labels"]=[[map[items] for items in label] for label in b["labels"]]

# %%
c["labels"]=[[map[items] for items in label] for label in c["labels"]]

# %%
label_names
# Out:
# array(['Taxon', 'Person', 'TemporalExpression', 'GeographicalLocation',
#        'O', 'Habitat'], dtype=object)

# %%
labels
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 labels                                                                                       │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'labels' is not defined

# %%
from seqeval.metrics import f1_score
from seqeval.metrics import accuracy_score
from seqeval.metrics import classification_report

# %%
#i1=tokenizer(df1["ann_text"].iloc[1,],is_split_into_words=True)

# %%
# calculates precision for 1:1:100 dataset with 50tp,20fp, 99tp,51fp
#from sklearn.metrics import f1_score,classification_report,accuracy_score,classification_report

# %%
# y_true = ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O']
# y_pred = ['O', 'O', 'IOB2', 'B-MISC', 'I-MISC', 'I-MISC', 'O']
# y=classification_report([y_true],[y_pred])
# Out:
# /opt/conda/lib/python3.10/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: IOB2 seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /opt/conda/lib/python3.10/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Out:
# ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O']

# %%
# Out:
# /opt/conda/lib/python3.10/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: IOB2 seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
# predictions = [l.copy()]
# predictions[0][1] = 'Person'
# y=metric.compute(predictions=predictions,references=[df1["ann_tag"].iloc[0,]] )
# y["Person"]["f1"]

# %%
def compute_metrics(eval_preds):
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)

    # Remove ignored index (special tokens) and convert to labels
    true_labels = [[label_names[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    all_metrics = metric.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": all_metrics["overall_precision"],
        "recall": all_metrics["overall_recall"],
        "f1": all_metrics["overall_f1"],
        "accuracy": all_metrics["overall_accuracy"],
     }
#     f1=metric.f1_score(true_predictions,true_labels, average='micro')
#     pr=metric.precision_score(true_predictions,true_labels, average='micro')
#     ac=metric.accuracy_score(true_predictions,true_labels, average='micro')
#     r=metric.recall_score(true_predictions,true_labels, average='micro')
#     return {
#         "precision":pr,
#        "recall": r,
#        "f1": f1,
#        "accuracy": ac,
#     }
    #return classification_report(true_labels,true_predictions)

# %%
id2label = {i: label for i, label in enumerate(label_names)}
label2id = {v: k for k, v in id2label.items()}

# %%
map
# Out:
# {'GeographicalLocation': 4,
#  'Habitat': 5,
#  'Taxon': 1,
#  'Person': 2,
#  'TemporalExpression': 3,
#  'O': 0,
#  -100: -100}

# %%
label2id
# Out:
# {'O': 0,
#  'Taxon': 1,
#  'Person': 2,
#  'TemporalExpression': 3,
#  'GeographicalLocation': 4,
#  'Habitat': 5}

# %%
from transformers import AutoModelForTokenClassification


model =AutoModelForTokenClassification.from_pretrained(model_checkpoint,
  id2label=id2label,
 label2id=label2id,ignore_mismatched_sizes=True , from_tf=True
)
# Out:
# ...
# All TF 2.0 model weights were used when initializing BertForTokenClassification.
#
# All the weights of BertForTokenClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForTokenClassification for predictions without further training.

# %%
from huggingface_hub import notebook_login

notebook_login("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")
access_token="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"

# %%
import wandb

# %%
wandb.login()
#5e298b6f3993d74bde7061a7e5c79bb8915ddee9
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
os.environ["WANDB_PROJECT"]="ner"

# save your trained model checkpoint to wandb
os.environ["WANDB_LOG_MODEL"]="true"

# turn off watch to log faster
os.environ["WANDB_WATCH"]="false"

# %%
import tensorflow as tf

# %%
optimizer1 = tf.keras.optimizers.Adam(learning_rate=1e-4)

# %%
from transformers import TrainingArguments

args = TrainingArguments(#"/kaggle/working/",
    "urbija/ner-bio-annotated-7-1",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate= 2e-05,
    #num_warmup_steps=2,
    num_train_epochs=5,
    warmup_ratio=0.2,
    
   
    
    
    
   
    weight_decay=0.1,
    report_to="wandb",
    push_to_hub=True,                   
    overwrite_output_dir = True,
)

# %%
# from transformers import BertConfig

# config = BertConfig.from_pretrained("bert-base-uncased")

# # Set the hidden dropout rate (e.g., 0.1 for 10% dropout)
# config.hidden_dropout_prob = 0.1

# # Assign the modified configuration to the model
# model.config = config

# %%
from datasets import Dataset
dataset_dict = {
    "input_ids": b["input_ids"],
    "attention_mask": b["attention_mask"],
    #"token_type_ids": b["token_type_ids"],
    "labels": b["labels"]
    
}
dataset = Dataset.from_dict(dataset_dict)

# %%
from datasets import Dataset
dataset_dict1 = {
    "input_ids": c["input_ids"],
    "attention_mask": c["attention_mask"],
    #"token_type_ids": b["token_type_ids"],
    "labels": c["labels"]
    
}
dataset1 = Dataset.from_dict(dataset_dict1)

# %%
label_names
# Out:
# array(['GeographicalLocation', 'Habitat', 'Taxon', 'Person',
#        'TemporalExpression'], dtype=object)

# %%
# h,t,g,p,t1=0,0,0,0,

# %%
# for x in df3["ann_tag"]:
    
#     for y in x:
#         if y=='Habitat':
#             l3.append(u)
            
#             h+=1
#         if y=='Taxon':
#             t+=1
#         if y=='Person':
#             p+=1
#         if y=='TemporalExpression':
#             t1+=1
#         if y=='GeographicalLocation':
            
#             g+=1
        
#     u+=1

# %%
#scheduler = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4, decay_steps=1000, decay_rate=0.9)

# %%
m.to_csv('/kaggle/working/dev.csv')

# %%
n.to_csv('/kaggle/working/train.csv')

# %%
from transformers import Trainer, EarlyStoppingCallback



trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset,
    eval_dataset=dataset1,
    
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    #optimizers=(optimizer1,None)
#     callbacks=[EarlyStoppingCallback(early_stopping_patience=3,load_best_model_at_end=True)]
)

h=trainer.train()
# Out:
# Cloning https://huggingface.co/urbija/ner-bio-annotated-7-1 into local empty directory.
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='335' max='335' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [335/335 2:20:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.277938</td>
#       <td>0.749693</td>
# ...

# %%
h
# Out:
# TrainOutput(global_step=335, training_loss=0.17099084427107625, metrics={'train_runtime': 8399.1828, 'train_samples_per_second': 0.317, 'train_steps_per_second': 0.04, 'total_flos': 696412518097920.0, 'train_loss': 0.17099084427107625, 'epoch': 5.0})

# %%
trainer.push_to_hub(commit_message="Training complete")
# Out:
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# To https://huggingface.co/urbija/ner-bio-annotated-7-1
#    97cad6f..471ed43  main -> main

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("urbija/ner-bio-annotated-7-1")
model = AutoModelForTokenClassification.from_pretrained("urbija/ner-bio-annotated-7")

# %%
from transformers import pipeline

# Replace this with your own checkpoint
model_checkpoint = "urbija/ner-bio-annotated-7-1"
token_classifier = pipeline(
    "token-classification", model=model_checkpoint, aggregation_strategy="simple"
)
token_classifier("Dipterocarpaceae. {Doona. Moist low country up to 2500 ft. or more ; rather common. Near Navalapitiya ; Ambagamuwa ; Singhe Raja Forest ; Morowak Korale (Capt. Walker) ; Pelmadulla (F. Lewis). Fl. April. Endemic. Easily recognised by the fine small raised reticulation of the upper surface of the leaf. The name 'Yakahalu' is applied, with different prefixes, to several other species of this family in South of Ceylon. This is called ' BeraliyaYakahalu ' in S. Prov. There appear to be several varieties recognised by the natives, and possibly more than one species are confounded here. The fruit of the Ambagamuwa tree (2200 ft.) is shorter and has smaller fruit-sep. than as above described. The fruits are dried, pounded, and made into flour for food, and are largely consumed when they can be got, but are said to be produced only every seventh year. It was abundant in the S. Prov. in 1887.")
# Out:
# [{'entity_group': 'Taxon',
#   'score': 0.99124146,
#   'word': 'dip',
#   'start': 0,
#   'end': 3},
#  {'entity_group': 'Taxon',
#   'score': 0.9906685,
#   'word': '##ter',
#   'start': 3,
#   'end': 6},
#  {'entity_group': 'Taxon',
#   'score': 0.9911823,
#   'word': '##oca',
#   'start': 6,
#   'end': 9},
#  {'entity_group': 'Taxon',
#   'score': 0.9914875,
#   'word': '##rp',
#   'start': 9,
#   'end': 11},
#  {'entity_group': 'Taxon',
#   'score': 0.9878619,
#   'word': '##aceae',
#   'start': 11,
#   'end': 16},
#  {'entity_group': 'Habitat',
#   'score': 0.43184796,
#   'word': 'moist',
#   'start': 26,
#   'end': 31},
#  {'entity_group': 'Habitat',
#   'score': 0.39878738,
#   'word': 'low',
#   'start': 32,
#   'end': 35},
#  {'entity_group': 'GeographicalLocation',
#   'score': 0.9429546,
#   'word': 'naval',
#   'start': 89,
#   'end': 94},
#  {'entity_group': 'GeographicalLocation',
#   'score': 0.9488363,
#   'word': '##ap',
#   'start': 94,
#   'end': 96},
# ...
